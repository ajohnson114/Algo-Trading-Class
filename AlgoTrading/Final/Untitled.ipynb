# %%
import sys
import pandas as pd
pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 1000)
pd.set_option('display.width', 1000)
import numpy as np
from statsmodels.tsa.stattools import coint

def zscore(series):
    return (series - series.mean()) / np.std(series)

# %%
data = pd.read_csv("input000-19.txt")
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                    test_calc_cointegration
# Attributes High               High               High               High               Low                Low                Low                Low                Open               Open               Open               Open               Close              Close              Close              Close              Volume      Volume     Volume      Volume     Adj Close           Adj Close          Adj Close                        Adj Close
# Symbols    AAPL               JNPR               MSFT               SPY                AAPL               JNPR               MSFT               SPY                AAPL               JNPR               MSFT               SPY                AAPL               JNPR               MSFT               SPY                AAPL        JNPR       MSFT        SPY        AAPL                JNPR               MSFT                                   SPY
# Date       NaN                NaN                NaN                NaN                NaN                NaN                NaN                NaN                NaN                NaN                NaN                NaN                NaN                NaN                NaN                NaN                NaN         NaN        NaN         NaN        NaN                 NaN                NaN                                    NaN
# 2001-01-02 0.2723214328289032 123.75             22.5               132.15625          0.2600446343421936 98.5625            21.4375            127.5625           0.265625           123.75             22.0625            132.0              0.265625           102.5625           21.6875            128.8125           452312000.0 22142800.0 82413200.0  8737500.0  0.22953693568706512 89.46620178222656  13.842705726623535       88.21560668945312
# 2001-01-03 0.2979910671710968 136.0              24.4375            136.0              0.2578125          97.25              21.5625            127.65625          0.2589285671710968 98.0               21.59375           128.3125           0.2924107015132904 132.0              23.96875           135.0              817073600.0 36720500.0 135962200.0 19431600.0 0.2526835501194     115.14482116699219 15.298779487609863        92.4530258178711
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                    ...
# 2005-12-23 2.6521427631378174 22.34000015258789  26.670000076293945 126.86000061035156 2.6178572177886963 22.1299991607666   26.440000534057617 126.41999816894531 2.648928642272949  22.149999618530273 26.520000457763672 126.77999877929688 2.619642972946167  22.299999237060547 26.639999389648438 126.76000213623047 229857600.0 3893900.0  30689200.0  27977300.0 2.2637360095977783  19.452497482299805 19.4095516204834          94.1402359008789
# 2005-12-27 2.684999942779541  22.59000015258789  26.850000381469727 127.05000305175781 2.641071319580078  22.059999465942383 26.450000762939453 125.37999725341797 2.642857074737549  22.309999465942383 26.68000030517578  126.95999908447266 2.651071310043335  22.100000381469727 26.459999084472656 125.47000122070312 590590000.0 3971000.0  37819000.0  44499500.0 2.2908942699432373  19.278032302856445 19.27840232849121        93.18220520019531
# 2005-12-28 2.6700000762939453 22.84000015258789  26.65999984741211  125.98999786376953 2.6185715198516846 22.0               26.350000381469727 125.5              2.6596429347991943 22.0               26.510000228881836 125.73999786376953 2.627500057220459  22.670000076293945 26.389999389648438 125.75             398115200.0 8147300.0  35444400.0  30764300.0 2.2705259323120117  19.775249481201172 19.22740936279297         93.3901596069336
# 2005-12-29 2.6364285945892334 22.719999313354492 26.5               125.95999908447266 2.5507142543792725 22.229999542236328 26.260000228881836 125.05999755859375 2.634999990463257  22.65999984741211  26.40999984741211  125.72000122070312 2.551785707473755  22.280000686645508 26.270000457763672 125.19000244140625 490025200.0 4640800.0  34495500.0  32788900.0 2.2050981521606445  19.435047149658203 19.139972686767578        92.9742660522461
# 2005-12-30 2.5867857933044434 22.450000762939453 26.309999465942383 125.05999755859375 2.5121428966522217 22.079999923706055 26.100000381469727 124.36000061035156 2.5325000286102295 22.15999984741211  26.149999618530273 124.80000305175781 2.567500114440918  22.299999237060547 26.149999618530273 124.51000213623047 624262800.0 4183000.0  49044600.0  44645600.0 2.218677282333374   19.452497482299805 19.052539825439453       92.46925354003906
#
# [1259 rows x 1 columns]

# %%
# Enter your code here. Read input from STDIN. Print output to STDOUT
def calc_cointegration(data):
    # We will use Adj Close price
    data = data['Adj Close']
    n = data.shape[1] # dimension of the matrix
    #initiate your matrix here with value 1
    pvalue_matrix = np.ones((1259,1))
    # get stock symbols from data using dataframe.columns
    symbols = data.columns
    # loop through symbols to get pairwise pvalue for cointegration test (you only need to calculate n*(n-1)/2 pvalues)
    # Please avoid hardcoding!
    
    return pvalue_matrix
